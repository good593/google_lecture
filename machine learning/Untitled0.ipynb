# %% [markdown]
# # Scikit-learn
# - https://github.com/teddylee777/machine-learning/tree/master/07-Scikit-Learn
# - https://www.geeksforgeeks.org/machine-learning/
# - https://www.w3schools.com/python/python_ml_getting_started.asp
